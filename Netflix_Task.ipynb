# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,Binarizer,StandardScaler,Normalizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,r2_score
from sklearn.svm import SVC,SVR
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix2.csv')

# %%
df
# Out:
#             Day  netflix: (India)
# 0    04-11-2021                43
# 1    05-11-2021                46
# 2    06-11-2021                50
# 3    07-11-2021                47
# 4    08-11-2021                40
# ..          ...               ...
# 175  28-04-2022                40
# 176  29-04-2022                43
# 177  30-04-2022                35
# 178  01-05-2022                44
# 179  02-05-2022                 0
#
# [180 rows x 2 columns]

# %%
df.iloc[179,1]=50

# %%
df
# Out:
#             Day  netflix: (India)
# 0    04-11-2021                43
# 1    05-11-2021                46
# 2    06-11-2021                50
# 3    07-11-2021                47
# 4    08-11-2021                40
# ..          ...               ...
# 175  28-04-2022                40
# 176  29-04-2022                43
# 177  30-04-2022                35
# 178  01-05-2022                44
# 179  02-05-2022                50
#
# [180 rows x 2 columns]

# %%
y=df['netflix: (India)']

# %%
y
# Out:
# 0      43
# 1      46
# 2      50
# 3      47
# 4      40
#        ..
# 175    40
# 176    43
# 177    35
# 178    44
# 179    50
# Name: netflix: (India), Length: 180, dtype: int64

# %%
x=df['Day']

# %%
x
# Out:
# 0      04-11-2021
# 1      05-11-2021
# 2      06-11-2021
# 3      07-11-2021
# 4      08-11-2021
#           ...
# 175    28-04-2022
# 176    29-04-2022
# 177    30-04-2022
# 178    01-05-2022
# 179    02-05-2022
# Name: Day, Length: 180, dtype: object

# %%
l=LabelEncoder()

# %%
x=l.fit_transform(x)

# %%
a=x[:,np.newaxis]

# %%
b=y[:,np.newaxis]
# Out:
# C:\Users\RAJA\AppData\Local\Temp/ipykernel_5644/3338251154.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   b=y[:,np.newaxis]

# %%
x_train, x_test, y_train, y_test =train_test_split(a,b,test_size=0.20,random_state=1)

# %%
model=SVR()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\RAJA\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR(kernel='sigmoid')

# %%
out=model.predict(x_test)

# %%
out
# Out:
# array([44.53573802, 44.60762915, 45.81528969, 45.25026709, 46.09037432,
#        44.52745417, 45.65396006, 44.62049276, 44.66678933, 45.78214866,
#        44.87516983, 44.80800251, 45.10542319, 44.75204282, 46.32858219,
#        46.39179298, 44.8400652 , 46.51441092, 46.40847489, 46.55364106,
#        45.74941772, 44.98560939, 44.57197099, 44.54482552, 44.54017349,
#        45.2061614 , 44.64465536, 46.26250127, 45.56305041, 46.65937765,
#        44.72769726, 46.65490588, 44.50954078, 46.57500775, 46.12521507,
#        44.73556418])

# %%
r2_score(y_test,out)
# Out:
# -0.07224659450625603

# %%
df2=pd.DataFrame(pd.date_range('02-05-2022',periods=180),columns=["Day"])

# %%
df2=l.fit_transform(df2)
# Out:
# C:\Users\RAJA\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
model.predict(s)
# Out:
# array([45.93621619, 45.89724392, 45.85638139, 45.81367403, 45.76917392,
#        45.72293971, 45.67503672, 45.6255368 , 45.57451837, 45.52206626,
#        45.46827166, 45.41323194, 45.35705051, 45.29983665, 45.24170524,
#        45.18277661, 45.1231762 , 45.0630343 , 45.00248576, 44.94166964,
#        44.88072885, 44.81980979, 44.75906197, 44.69863755, 44.63869099,
#        44.57937851, 44.52085774, 44.46328718, 44.40682574, 44.35163227,
#        44.29786505, 44.24568131, 44.19523671, 44.14668487, 44.10017682,
#        44.05586058, 44.01388057, 43.97437721, 43.93748641, 43.90333909,
#        43.87206072, 43.84377093, 43.81858302, 43.79660358, 43.77793212,
#        43.76266063, 43.75087332, 43.7426462 , 43.73804685, 43.73713409,
#        43.73995775, 43.74655842, 43.75696727, 43.77120587, 43.78928603,
#        43.8112097 , 43.83696888, 43.86654554, 43.89991163, 43.93702903,
#        43.97784964, 44.02231538, 44.07035832, 44.1219008 , 44.17685552,
# ...

# %%
df2

# %%
s=df2[:,np.newaxis]

# %%
m=LinearRegression()

# %%
m.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
o=m.predict(x_test)

# %%
r2_score(o,y_test)
# Out:
# -971.536354502315

# %%
df=pd.read_csv('CarPrice_Assignment.csv')

# %%
df.fillna(method='ffill')
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
from sklearn.feature_selection import chi2

# %%
from sklearn.feature_selection import SelectKBest

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#      fueltype  aspiration  doornumber  carbody  drivewheel  enginelocation  \
# 0           1           0           1        0           2               0
# 1           1           0           1        0           2               0
# 2           1           0           1        2           2               0
# 3           1           0           0        3           1               0
# 4           1           0           0        3           0               0
# ..        ...         ...         ...      ...         ...             ...
# 200         1           0           0        3           2               0
# 201         1           1           0        3           2               0
# 202         1           0           0        3           2               0
# 203         0           1           0        3           2               0
# 204         1           1           0        3           2               0
#
# ...

# %%
y=df['price']

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
l=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='O':
        df[i]=l.fit_transform(df[i])

# %%
for i in x.columns:
    if x[i].dtypes=='O':
        x[i]=l.fit_transform(x[i])

# %%
x
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         1           0           1        0
# 1         2          3        3         1           0           1        0
# 2         3          1        1         1           0           1        2
# 3         4          2        4         1           0           0        3
# 4         5          2        5         1           0           0        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         1           0           0        3
# 201     202         -1      138         1           1           0        3
# 202     203         -1      140         1           0           0        3
# 203     204         -1      142         0           1           0        3
# 204     205         -1      143         1           1           0        3
#
# ...

# %%
mx=MinMaxScaler(feature_range=(0,1))

# %%
df.drop(['car_ID','CarName','symboling'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14416/3007188614.py in <module>
# ----> 1 df.drop(['car_ID','CarName','symboling'],axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#      fueltype  aspiration  doornumber  carbody  drivewheel  enginelocation  \
# 0           1           0           1        0           2               0
# 1           1           0           1        0           2               0
# 2           1           0           1        2           2               0
# 3           1           0           0        3           1               0
# 4           1           0           0        3           0               0
# ..        ...         ...         ...      ...         ...             ...
# 200         1           0           0        3           2               0
# 201         1           1           0        3           2               0
# 202         1           0           0        3           2               0
# 203         0           1           0        3           2               0
# 204         1           1           0        3           2               0
#
# ...

# %%
mt=SelectKBest(score_func=chi2,k=4)

# %%
er=mt.fit(x,y.astype('int'))

# %%
rt=er.transform(x)

# %%
rt.shape
# Out:
# (205, 4)

# %%
s=er.scores_

# %%
np.set_printoptions(precision=2)

# %%
print(s)
# Out:
# [1.89e+01 1.65e+02 1.10e+02 5.61e+01 4.68e+01 2.02e+02 7.43e+01 1.78e+02
#  1.42e+01 2.20e+01 2.16e+04 7.03e+01 6.08e+01 2.78e+03 2.50e+02 4.32e+00
#  5.95e+00 2.99e+02 3.05e+03 8.91e+03 3.43e+02 3.11e+02]

# %%
w=mt.get_support()
w
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False,  True, False, False,  True, False, False, False, False,
#         True,  True, False, False])

# %%
col=df.columns
for i in range(len(w)):
    if w[i]==True:
        print(col[i])
# Out:
# curbweight
# enginesize
# horsepower
# peakrpm

# %%
a=['curbweight','enginesize','horsepower','peakrpm']

# %%
x=df[a]

# %%
x
# Out:
#      curbweight  enginesize  horsepower  peakrpm
# 0          2548         130         111     5000
# 1          2548         130         111     5000
# 2          2823         152         154     5000
# 3          2337         109         102     5500
# 4          2824         136         115     5500
# ..          ...         ...         ...      ...
# 200        2952         141         114     5400
# 201        3049         141         160     5300
# 202        3012         173         134     5500
# 203        3217         145         106     4800
# 204        3062         141         114     5400
#
# [205 rows x 4 columns]

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.20,random_state=60)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
out=model.predict(x_test)

# %%
out
# Out:
# array([17860.89, 10789.25,  6424.37, 10935.48,  9640.28,  5556.19,
#         6034.88, 35536.99,  9065.15, 18611.35, 13907.81, 22310.19,
#        13394.66,  9065.15, 13394.66, 17998.73,  8640.8 , 18287.35,
#        17905.44,  6575.67,  7733.12,  9428.42,  7010.76, 18380.12,
#        12913.1 , 22716.53,  6151.48, 17404.22, 24336.15, 11158.27,
#        23618.95,  9853.57, 12208.44, 10808.57, 17082.5 ,  9172.23,
#        26564.67, 14509.31,  5333.42, 10844.83, 36900.65])

# %%
r2_score(y_test,out)*100
# Out:
# 87.33715333299075
