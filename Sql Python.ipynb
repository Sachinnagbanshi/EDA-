# %% [markdown]
# ## Question 1

# %%
import mysql.connector as m
mydb=m.connect(host='localhost',user='root',password='sachin')
x=mydb.cursor()

# %%
def insert(x):
    import pandas as pd
    x.execute(f"use {input('Enter Database Name: ')}")
    table_name=input("Enter Table Name: ")
    x.execute(f"Select * from {table_name};")
    df=pd.DataFrame(x.fetchall(),columns=x.column_names)
    columns=df.columns
    no_of_rows=int(input("How many rows do you want to enter?: "))
    for i in range(0,no_of_rows):
        detail=()
        for j in range(len(columns)):
            if df[columns[j]].dtype=="int64":
                detail+=(int(input(f"Enter the 'Int' value of {columns[j]}: ")),)
            elif df[columns[j]].dtype=="O":
                detail+=(input(f"Enter the 'char' value of {columns[j]}: "),)
            elif df[columns[j]].dtype=="float64":
                detail+=(float(input(f"Enter the 'float' value of {columns[j]}: ")),)
        x.execute(f"Insert into {table_name} values {detail};")
    x.execute('set autocommit=1')

# %%
insert(x)
# Out:
# Enter Database Name: customers
# Enter Table Name: marks
# How many rows do you want to enter?: 1
# Enter the 'Int' value of roll_no: 45
# Enter the 'char' value of first_name: sachin
# Enter the 'char' value of last_name: nag
# Enter the 'Int' value of marks: 64

# %% [markdown]
# ## Question 2

# %%
def show(x):
    import pandas as pd
    x.execute('show databases')
    x.execute(f"Use {input('Enter DataBase Name: ')}")
    x.execute('show tables')
    x.execute(f"select * from {input('Enter Table Name: ')}")
    data=x.fetchall()
    column=x.column_names
    df=pd.DataFrame(data,columns=column)
    return df

# %%
s=show(x)

# %%
s
# Out:
#        #                   Name    Type1   Type2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...
